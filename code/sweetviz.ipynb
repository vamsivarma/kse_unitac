# %%
# %matplotlib inline
import pandas as  pd
df = pd.read_csv('../data/air_quality.csv')
df.rename(columns={'value': 'indicator_value'}, inplace=True)
# importing sweetviz
import sweetviz as sv
#analyzing the dataset
air_quality_report = sv.analyze(df)
#display the report
air_quality_report.show_html('air_quality.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report air_quality.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.columns
# Out:
# Index(['id_station', 'indicator_code', 'indicator_name', 'indicator_dimension',
#        'value', 'datetime', 'source'],
#       dtype='object')

# %%
! pip list
# Out:
# Package                   Version
# ------------------------- --------------
# aenum                     3.1.15
# alembic                   1.13.1
# altair                    5.2.0
# annotated-types           0.6.0
# anyio                     4.3.0
# archspec                  0.2.3
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-generator           1.10
# async-lru                 2.0.4
# attrs                     23.2.0
# autoviz                   0.1.803
# Babel                     2.14.0
# backoff                   2.2.1
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.7.0
# bokeh                     2.4.3
# boltons                   23.1.1
# Bottleneck                1.3.8
# branca                    0.7.1
# Brotli                    1.1.0
# cached-property           1.5.2
# cachetools                5.3.3
# ...
